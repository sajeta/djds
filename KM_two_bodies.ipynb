# %%
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
ts = np.linspace(-5000,5000,10000)

# %%
y0 = [1,0,0,1]
def fun(f, t):
    return [f[2], f[3], -f[0]/(sqrt(f[0]^2+f[1]^2))^3, -f[1]/(sqrt(f[0]^2+f[1]^2))^3]
ys = odeint(fun, y0, ts)
data = [(x,y) for x,y,i,j in ys]
list_plot(data)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
y0 = [1,0,0,0.8]
def fun(f, t):
    return [f[2], f[3], -f[0]/(sqrt(f[0]^2+f[1]^2))^3, -f[1]/(sqrt(f[0]^2+f[1]^2))^3]
ys = odeint(fun, y0, ts)
data = [(x,y) for x,y,i,j in ys]
list_plot(data)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
y0 = [-5,5,0.5,0]
def fun(f, t):
    return [f[2], f[3], -f[0]/(sqrt(f[0]^2+f[1]^2))^3, -f[1]/(sqrt(f[0]^2+f[1]^2))^3]
ys = odeint(fun, y0, ts)
data = [(x,y) for x,y,i,j in ys]
list_plot(data)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
y0 = [-10^3,20,0.15,0]
def fun(f, t):
    return [f[2], f[3], -f[0]/(sqrt(f[0]^2+f[1]^2))^3, -f[1]/(sqrt(f[0]^2+f[1]^2))^3]
ys = odeint(fun, y0, ts)
data = [(x,y) for x,y,i,j in ys]
list_plot(data, xmin=-100, xmax=100, ymin=-100, ymax=100)
# Out:
# Graphics object consisting of 1 graphics primitive
